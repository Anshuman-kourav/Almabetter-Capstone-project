# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshuman-kourav/Almabetter-Capstone-project/blob/main/EDA_Submission_Play_Store_App_Review_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -**Play Store App Review Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Anshuman singh kourav(Individual)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Google Play Store hosts millions of apps across diverse categories, catering to a global audience. Understanding the factors that contribute to an app's success is crucial for developers and businesses looking to capture market share and increase user engagement. This project dives deep into the Google Play Store data to identify key factors influencing app success and engagement, leveraging a comprehensive analysis of app attributes and customer reviews.
#
# The dataset consists of detailed information on various app features, such as category, rating, size, pricing model, content rating, and genres. Additionally, customer reviews provide insights into user experiences and sentiments, offering a complete view of app performance. By employing an exploratory data analysis (EDA) approach, we seek to uncover trends, patterns, and actionable insights that can drive business strategies and inform app development.
#
# The project employs Pandas for efficient data manipulation and NumPy for computational operations, ensuring a streamlined exploration process. Visualizations are crafted using Matplotlib and Seaborn to represent complex data patterns effectively. At the heart of this analysis is the exploration of relationships between variables, such as how app category, pricing, and size impact user ratings and installs. Sentiment analysis of customer reviews offers a deeper understanding of user feedback, revealing aspects of the app experience that matter most to users.
#
# A crucial part of the project involves handling missing values and outliers in the data. For example, missing ratings can be imputed using the median of the respective category to ensure a balanced analysis. Outliers in numerical columns, like app size or price, are identified and managed to prevent skewed interpretations. The data is meticulously cleaned and transformed, converting variables like 'Installs' and 'Size' into numerical formats to facilitate meaningful comparisons.
#
# Visualizations play a key role in forming insights. We use bar plots to display the distribution of apps across categories and identify which ones have the highest average ratings. Scatter plots and correlation heatmaps illustrate relationships between variables, such as the connection between app size and installs or pricing and user ratings. Sentiment analysis results, represented through count plots, shed light on the overall customer perception of apps in various categories.
#
# From this analysis, we identify pivotal factors that drive app engagement and success. For example, free apps in certain categories tend to attract more downloads, while apps with consistent updates and higher sentiment polarity ratings often receive better user ratings. These insights can help developers and businesses make informed decisions regarding app development, pricing strategies, and user experience enhancements. By offering a comprehensive understanding of the Play Store market dynamics, this project serves as a valuable tool for stakeholders aiming to optimize their app strategies and achieve higher user engagement.
#
# ---

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Anshuman-kourav/Almabetter-Capstone-project/tree/main

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The Google Play Store is crowded with millions of apps, making it challenging for developers and businesses to understand the factors that drive app success and user engagement. Despite having access to various app attributes and user reviews, there is a need for an in-depth analysis that identifies the key elements contributing to higher app ratings, user installs, and positive customer feedback. How can developers leverage data insights to enhance app features, improve user satisfaction, and strategically position their apps for success?.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective is to explore and analyze the Google Play Store data to identify the key factors influencing app engagement and success. By examining app attributes, user ratings, and customer reviews, we aim to:
#
# 1. Uncover trends and patterns that highlight what makes an app successful.
#
# 2. Provide actionable insights to developers and businesses for app enhancement
#    and market positioning.
#
# 3. Develop data-driven strategies for app development, pricing, and user
#
#    engagement to maximize reach and profitability.
#
# 4. Offer a comprehensive view of customer sentiments, helping businesses
#    prioritize features and improvements that matter most to users.
#
# This project will guide stakeholders in making informed decisions that align with user preferences and market demands, ultimately contributing to the app's success in the competitive Play Store environment.
#
#
#
#
#
#
# .

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset

df_psdata = pd.read_csv('/content/drive/MyDrive/Data/Play Store Data.csv')
df_review = pd.read_csv('/content/drive/MyDrive/Data/Reviews.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

#Display the Play Store App Data
print('Play Store Data Overview:')
df_psdata.head()
# Out:
# Play Store Data Overview:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
#Display the User Reviews Data
print('User Reviews Data Overview:')
df_review.head()
# Out:
# User Reviews Data Overview:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

print('Play Store Data Rows Count:',df_psdata.shape[0])
print('Play Store Data Columns Count:',df_psdata.shape[1])
print('User Reviews Data Rows Count:',df_review.shape[0])
print('User Reviews Data Columns Count:',df_review.shape[1])
# Out:
# Play Store Data Rows Count: 10841
# Play Store Data Columns Count: 13
# User Reviews Data Rows Count: 64295
# User Reviews Data Columns Count: 5

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

print('Play Store Data info:')
df_psdata.info()
print('\n')
print('User Reviews Data info:')
df_review.info()
# Out:
# Play Store Data info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB
#
#
# User Reviews Data info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

print('Play Store Data Duplicate Value Count:',len(df_psdata[df_psdata.duplicated()]))
print('User Reviews Data Duplicate Value Count:',len(df_review[df_review.duplicated()]))
# Out:
# Play Store Data Duplicate Value Count: 483
# User Reviews Data Duplicate Value Count: 33616

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print('Null values in play store data:',df_psdata.isna().sum(),sep='\n')
print('\n')
print('Null values in User reviews data:',df_review.isnull().sum(),sep='\n')
# Out:
# Null values in play store data:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64
#
#
# Null values in User reviews data:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %% [markdown]
# Function to calculate the percentage of null values in each columns

# %%
def null_percentage(data_fm):
  null_info = pd.DataFrame(index=data_fm.columns)
  null_info["Datatypes"] = data_fm.dtypes
  null_info["Not null value"] = data_fm.count()
  null_info["Null value"] = data_fm.isnull().sum()
  null_info["null value (%)"] = round(data_fm.isnull().mean()*100,2)
  return null_info

# Display the percentage of null value for Play Store data
print('Null value (%) in play store Data:',null_percentage(df_psdata),sep='\n')
print('\n')

# Display the percentage of null value for User reviews data
print('Null value (%) in User Reviews Data:',null_percentage(df_review),sep='\n')
# Out:
# Null value (%) in play store Data:
#                Datatypes  Not null value  Null value  null value (%)
# App               object           10841           0            0.00
# Category          object           10841           0            0.00
# Rating           float64            9367        1474           13.60
# Reviews           object           10841           0            0.00
# Size              object           10841           0            0.00
# Installs          object           10841           0            0.00
# Type              object           10840           1            0.01
# Price             object           10841           0            0.00
# Content Rating    object           10840           1            0.01
# Genres            object           10841           0            0.00
# Last Updated      object           10841           0            0.00
# Current Ver       object           10833           8            0.07
# ...

# %%
# Visualizing the missing values

#Checking null values by plotting Heatmap for Play Store Data
print('null values Heatmap for Play Store Data')
sns.heatmap(df_psdata.isnull(),cbar=False)
plt.show()
# Out:
# null values Heatmap for Play Store Data

# %%
# Visualizing the missing values

#Checking null values by plotting Heatmap for User Reviews Data
print('null values Heatmap for User Reviews Data')
sns.heatmap(df_review.isnull(),cbar=False)
plt.show()
# Out:
# null values Heatmap for User Reviews Data

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The datasets are associated with the mobile application industry, focusing on the Android platform.
#
# Play Store dataset: 10,841 rows, 13 columns, 483 instances of duplicated rows.
#
# Missing values in columns: Rating' (13,60% null values), Type (0.01% null values), 'Content Rating' (0.01% null values), 'Current Ver
# (0.07% null values), 'Android Ver' (0.03%
# values).
#
# User reviews dataset: 64,295 rows, 5 columns, 33,616 instances of duplicated rows.
#
# Missing values in columns: Translated_Review (41.79% null value), 'Sentiment' (41.78% null value), 'Sentiment Polarity' (41.78% null
# values), 'Sentiment_Subjectivity (41.78% null values).
#
# Primary aim: Uncover key factors contributing to app engagement and success in the Android market using this data.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

print("Play Store Dataset Columns",df_psdata.columns,sep='\n')
print("User Reviews Dataset Columns",df_review.columns,sep='\n')
# Out:
# Play Store Dataset Columns
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')
# User Reviews Dataset Columns
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe

print("Play Store Dataset Description",df_psdata.describe(include='all'),sep='\n',end ='\n\n')
print("User Reviews Dataset Description",df_psdata.describe(include='all'),sep='\n')
# Out:
# Play Store Dataset Description
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Description of the Play Store Data Set**
#
# **App**: The name of the app.
#
# **Category**: The category of the app (e.g., Games, Education, etc.).
#
# **Rating**: The average user rating of the app (out of 5 stars).
#
# **Reviews**: The total number of user reviews for the app.
#
# **Size**: The size of the app in megabytes.
#
# **Installs**: The estimated number of times the app has been installed.
#
# **Type**: Whether the app is free or paid.
#
# **Price**: The price of the app (if paid).
#
# **Content Rating**: The age rating of the app (e.g., Everyone, Teen, Mature 17+, etc.).
#
# **Genres**: Additional categories that the app can belong to (e.g., Puzzle, Role-playing, Adventure, etc.).
#
# **Last Updated**: The date the app was last updated.
#
# **Current Ve**r: The current version of the app.
#
# **Android Ver**: The minimum Android version required to run the app.
#
#
#
#
#
# **Description of the User Reviews Data Set**
#
# **App**: The name of the app that is being reviewed.
#
# **Translated Review**: The English translation of the user's review. It is possible that the original review was in a different language.
#
# **Sentiment**: The reviewer's attitude towards the app, categorized as "Positive", "Negative", or "Neutral".
#
# **Sentiment Polarity**: A score ranging from -1 (negative) to 1 (positive) that indicates the reviewer's sentiment in more detail.
#
# **Sentiment Subjectivity**: A score between 0 and 1 that indicates how much the reviewer's opinion aligns with the general public's opinion. A higher score suggests the review expresses more personal opinions, while a lower score suggests it contains more factual information.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# Printing Unique Values for each variable in Play Store Dataset

print("Unique Values for each variable in Play Store Dataset",end='\n\n')

for i in df_psdata.columns.tolist():
  print("No. of unique values in",i ,"is-->",df_psdata[i].nunique())

print('\n')

# Printing Unique Values for each variable in User Reviews Dataset
print("Unique Values for each variable in User Reviews Dataset",end='\n\n')

for i in df_review.columns.tolist():
  print("No. of unique values in",i ,"is-->",df_review[i].nunique())
# Out:
# Unique Values for each variable in Play Store Dataset
#
# No. of unique values in App is--> 9660
# No. of unique values in Category is--> 34
# No. of unique values in Rating is--> 40
# No. of unique values in Reviews is--> 6002
# No. of unique values in Size is--> 462
# No. of unique values in Installs is--> 22
# No. of unique values in Type is--> 3
# No. of unique values in Price is--> 93
# No. of unique values in Content Rating is--> 6
# No. of unique values in Genres is--> 120
# No. of unique values in Last Updated is--> 1378
# No. of unique values in Current Ver is--> 2832
# No. of unique values in Android Ver is--> 33
#
#
# Unique Values for each variable in User Reviews Dataset
#
# No. of unique values in App is--> 1074
# No. of unique values in Translated_Review is--> 27994
# No. of unique values in Sentiment is--> 3
# No. of unique values in Sentiment_Polarity is--> 5410
# No. of unique values in Sentiment_Subjectivity is--> 4474

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Print the rows with non-numeric characters in 'Reviews' column

non_numeric_reviews =df_psdata[df_psdata['Reviews'].str.contains(r'\D')]
print("Rows with non-numeric characters in 'Reviews' column:")
non_numeric_reviews
# Out:
# Rows with non-numeric characters in 'Reviews' column:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# The row at index 10472 contains data that is entirely incorrect or irrelevant.
# The row is deemed unusable or misleading for the analysis, removing it ensures the integrity and accuracy of the overall dataset.

df_psdata = df_psdata.drop(index=10472)

#Resetting the index ensures that the DataFrame has continuous and ordered indices after droping the a row.
df_psdata = df_psdata.reset_index(drop=True)

# %%
# Convert the 'Reviews' column to integer datatype

df_psdata['Reviews'] = df_psdata['Reviews'].astype(int)

# %%
# Convert the 'Last Updated' column to datetime format

df_psdata['Last Updated'] = pd.to_datetime(df_psdata['Last Updated'])

# %%
# Creating a function drop_dollar, which drops the $ symbol if present and returns the value as a float.
def drop_dollar(value):
  if '$' in value:
    return float(value[1:])
  else:
    return float(value)

# Applying the Drop_dollar function to the 'Price' column
df_psdata['Price'] = df_psdata['Price'].apply(lambda x: drop_dollar(x))

# %%
def drop_plus(value):
  '''
   This function drops the symbol if present and returns the value with int datatype.
   If the value is not a valid integer, return np.nan.
  '''
  try:

    if '+' and ',' in value:
      return int(value[:-1].replace(',',''))
    elif '+' in value:
      return int(value[:-1])
    else:
      return int(value)
  except ValueError:
    return 0

    ''' The 'install' column now contains integer values representing the minimun number of time an app has been installed.
        An 'install' value of 0 means the app has not been insitalled.
        An 'install' value of 1 means the app has been installed at least once.
        An  'install' value of 1000000  means the app has been installed by the least once million users, and so on
    '''
# The Drop_plus function applied to the 'installs' column
df_psdata['Installs'] = df_psdata['Installs'].apply(lambda x: drop_plus(x))

# %%
#Defining a function to convert all the entries in KB to MB and then converting them to float datatype.

def kb_to_mb(entry):

    """
    Converts size entries to MB. Returns as a float if in megabytes (M), or converts and rounds to 4 decimal places if in kilobytes (k).
    Returns the original entry if not in either format or if any conversion exception occurs.
    """
    try:
        if 'M' in entry:
            return float(entry[:-1])
        elif 'k' in entry:
            return round(float(entry[:-1]) / 1024, 4)
        else:
            return entry
    except:
        return entry

# The kb to mb funtion applied to the size column
df_psdata['Size'] = df_psdata['Size'].apply(lambda x: kb_to_mb(x))

# %%
# veryfing the data types information after type conversion

print("Play Store Updated Data info:")
df_psdata.info()
# Out:
# Play Store Updated Data info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
# Extract non-float values in 'Size' column
non_float_size_values = df_psdata['Size'][~df_psdata['Size'].apply(lambda x: isinstance(x, float))]

# Calculate the percentage of non-float values in 'Size' column
percentage_non_float = (len(non_float_size_values) / len(df_psdata['Size'])) * 100

# Print the result
print(f"Non-float values in the 'Size' column: {non_float_size_values.unique()}")

print(f"Percentage of non-float values in the 'Size' column: {percentage_non_float:.2f}%")


# Varies with device' being the only non-float entry, constituting 15.64%,
# led to the decision to retain rows with this value in the 'Size' column.
# Out:
# Non-float values in the 'Size' column: ['Varies with device']
# Percentage of non-float values in the 'Size' column: 15.64%

# %%
# Show Dataset Rows & Columns count Before Removing Duplicates
print('Shape Before Removing Duplicates:')

print('Play Store Data Rows count:',df_psdata.shape[0])
print('Play Store Data Columns count:',df_psdata.shape[1])

print('User Reviews Data Rows count:',df_review.shape[0])
print('User Reviews Data Columns count:',df_review.shape[1],end='\n\n')

# Remove duplicates
df_review.drop_duplicates(inplace=True)
df_psdata.drop_duplicates(inplace=True)

#Show Dataset Rows and Columns count after Removing Duplicates
print("Shape After Removing Duplicates:")
print('Play Store Data Rows Count:',df_psdata.shape[0])
print('Play Store Data Columns Count:',df_psdata.shape[1])
print('User Reviews Data Rows Count:',df_review.shape[0])
print('User Reviews Data Columns Count:',df_review.shape[1])
# Out:
# Shape Before Removing Duplicates:
# Play Store Data Rows count: 10840
# Play Store Data Columns count: 13
# User Reviews Data Rows count: 64295
# User Reviews Data Columns count: 5
#
# Shape After Removing Duplicates:
# Play Store Data Rows Count: 10357
# Play Store Data Columns Count: 13
# User Reviews Data Rows Count: 30679
# User Reviews Data Columns Count: 5

# %%
# Fill missing values for numerical columns with the median and categorical with the mode
# For Play Store

df_psdata['Rating'].fillna(df_psdata['Rating'].median(), inplace=True)
df_psdata['Type'].fillna(df_psdata['Type'].mode()[0], inplace=True)

df_psdata['Content Rating'].fillna(df_psdata['Content Rating'].mode()[0], inplace=True)
df_psdata['Current Ver'].fillna('Varies with device', inplace=True)

df_psdata['Android Ver'].fillna('Vasies with device', inplace=True)

# For User Reviews
df_review['Sentiment_Polarity'].fillna(df_review['Sentiment_Polarity'].median(),
inplace=True)

df_review['Sentiment_Subjectivity'].fillna(df_review['Sentiment_Subjectivity'].median(), inplace=True)
df_review['Sentiment'].fillna(df_review['Sentiment'].mode()[0], inplace=True)

df_review['Translated_Review'].fillna('No review', inplace=True)

#Check missing values again to confirm
user_reviews_missing_updated = df_review.isnull().sum()

play_store_missing_updated = df_psdata.isnull().sum()

print('\nUpdated number of missing values in Play Store dataset:')
print(play_store_missing_updated)

print('Updated number of missing values in User Reviews dataset:')
print(user_reviews_missing_updated)
# Out:
# Updated number of missing values in Play Store dataset:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64
# Updated number of missing values in User Reviews dataset:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
# Visualizing Outliers through Box Plots
# Set up the figure with subplots

fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Box plot for Reviews
sns.boxplot(ax=axes[0], x=df_psdata['Reviews'])

axes[0].set_title('Box Plot Reviews')

# Box plot for Installs
sns.boxplot(ax=axes[1], x=df_psdata['Installs'])

axes[1].set_title('Box Plot - Installs')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
# Show Dataset Rows & Columns count Before Removing Outliers
print('Shape Before Removing Outliers:')

print('Play Store Data Rows count:',df_psdata.shape[0])
print('Play Store Data Columns count:',df_psdata.shape[1])

print('User Reviews Data Rows count:',df_review.shape[0])
print('User Reviews Data Columns count:',df_review.shape[1],end='\n\n')

#Removing Outliers from Data
# Define the quantile range

quantile_low = 0.05
quantile_high = 0.95

# Remove outliers for Reviews column
df_psdata = df_psdata[(df_psdata['Reviews'] >= df_psdata['Reviews'].quantile(quantile_low)) &
(df_psdata['Reviews'] <= df_psdata['Reviews'].quantile (quantile_high))]

# Remove outliers for Installs column
df_psdata = df_psdata[(df_psdata['Installs'] >= df_psdata['Installs'].quantile (quantile_low)) &
(df_psdata['Installs'] <= df_psdata['Installs'].quantile(quantile_high))]

# Show Dataset Rows & Columns count After Removing Outliers
print('Shape After Removing Outliers:')

print('Play Store Data Rows count:',df_psdata.shape[0])
print('Play Store Data Columns Count:',df_psdata.shape[1])
print('User Reviews Data Rows Count:',df_review.shape[0])
print('User Reviews Data Columns Count:',df_review.shape[1])
# Out:
# Shape Before Removing Outliers:
# Play Store Data Rows count: 10357
# Play Store Data Columns count: 13
# User Reviews Data Rows count: 30679
# User Reviews Data Columns count: 5
#
# Shape After Removing Outliers:
# Play Store Data Rows count: 9404
# Play Store Data Columns Count: 13
# User Reviews Data Rows Count: 30679
# User Reviews Data Columns Count: 5

# %%
df_psdata.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dropping Unnecessary Columns for Analysis from Play Store and User Reviews Dataset

# Drop the 'current ver' Column from df_psdata

df_psdata = df_psdata.drop('Current Ver',axis=1)

# Drop the 'Translateted_Review' Column from df_review

df_review = df_review.drop('Translated_Review',axis=1)

print('Shape After Removing  Unnecessary Columns:')
# Data set Rows and Columns count
print('Play Store Data Rows count:',df_psdata.shape[0])
print('Play Store Data Columns Count:',df_psdata.shape[1])
print('User Reviews Data Rows Count:',df_review.shape[0])
print('User Reviews Data Columns Count:',df_review.shape[1])
# Out:
# Shape After Removing  Unnecessary Columns:
# Play Store Data Rows count: 9404
# Play Store Data Columns Count: 12
# User Reviews Data Rows Count: 30679
# User Reviews Data Columns Count: 4

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The following actions were taken to make the datasets analysis-ready:
#
# 1. Identifying Non-Numeric Reviews:
#
# * Checked and printed rows with non-numeric characters in the 'Reviews' column.
#
# 2. Removing Irrelevant Row:
#
# * Dropped the row at index 10472 as it contained incorrect or irrelevant data,
#   ensuring dataset integrity.
#
# 3. Converting Reviews to Integer:
#
# * Converted the 'Reviews' column to integer data type for numerical analysis.
#
# 4. Converting Last Updated to Datetime:
#
# * Converted the 'Last Updated' column to datetime format for temporal analysis.
#
# 5. Handling Price Values:
#
# * Created a function (drop_dollar) to drop the '$' symbol and convert the
#   'Price' column to float data type.
#
# 6. Handling Installs Values:
#
# * Created a function (drop_plus) to drop the '+' symbol and convert the
#  'Installs' column to integer data type.
#
# 7. Converting Size Entries:
#
# * Created a function (kb_to_mb) to convert size entries to MB and handle 'k' or
#  'M' units.
#
# 8. Verifying Data Types:
#
# * Checked and printed the updated data type information after the type
#   conversion.
#
# 9. Removing Duplicates:
#
# * Removed duplicate rows from both the Play Store and User Reviews datasets.
#
# 10. Handling Missing Values:
#
# * Filled missing values for numerical columns with the median and categorical
#   columns with the mode.
#
# * Checked and printed the updated number of missing values in both datasets.
#
# 11. Handling Outliers:
#
# * Visualized outliers through box plots for Reviews and Installs.
#
# * Removed outliers from data based on quantile range (5% to 95%) for Reviews
#   and Installs.
#
# 12. Removing Unnecessary Columns:
#
# * Certain columns were considered non-significant to the analysis and were      subsequently dropped. Specifically, the 'Current Ver'
#
# * column in the Play Store Dataset (df psdata) and the 'Translated_Review'
#   column in the User Reviews Dataset (df review) were excluded.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Distribution of Sentiment Polarity
# Set up the Visualization Settings

sns.set(style='whitegrid')

# plot distribution of Sentiment Polarity

plt.figure(figsize=(10,5))
plt.title('Distribution of Sentiment Polarity',size=20)
sns.histplot(df_review['Sentiment_Polarity'],bins=50,kde=True)
plt.xlabel('Sentiment Polarity',size=15)
plt.ylabel('Frequency',size=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram charts prove valuable when visualizing the distribution of a singular numerical variable. In this context, employing a Histogram chart enabled me to depict the polarity of reviews, offering insights into their positive or negative nature.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Positive sentiment dominates:** The histogram shows a clear peak towards the positive side, indicating most apps have predominantly positive
#
# sentiment amongst users. This suggests most apps are well-received and appreciated by users.
#
# **Presence of negative sentiment:** While less prominent, the histogram also shows a tail on the negative side. This suggests some apps do experience negative feedback and dissatisfaction from users. Analyzing this negativity can highlight areas for improvement or issues requiring developer attention.
#
# **Distribution shape:** The shape of the distribution (skewed right) suggests a higher concentration of apps with significantly positive sentiment compared to those with profoundly negative sentiment. This implies a general trend of user satisfaction with most apps on the Play Store.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# 1.**Overall Positive Sentiment:**
#
# **Potential Positive Impact:** The dominance of positive sentiment indicates that most apps are well-received, which can contribute to positive user experiences, retention, and potentially attract new users. Positive reviews and satisfaction often lead to positive word-of-mouth contenting to the app's popularity and success.
#
# 2.**Distribution Shape and User Satisfaction:**
#
# **Positive Growth Opportunity:** The right-skewed distribution suggests a higher concentration of positively received apps. This implies a general trend of user satisfaction, which can contribute to positive growth. Developers can leverage this positive sentiment to reinforce features users appreciate and further enhance user experiences.
#
# **Negative Growth Consideration**
#
# 1.**Presence of Negative Sentiment:**
# Potential Negative Impact: The existence of negative sentiment, although less prominent, indicates that some apps face dissatisfaction. Unaddressed negative feedback can result in user churn, negative reviews, and a decline in the app's reputation. It may lead to users seeking alternative apps that better meet their expectations.
#
# 2.**Area of Improvement:**
#    **Negative Growth Risk:**The presence of negative sentiment provides insights into areas that may require improvement. if these issues are not addressed promptly, they could lead the negative growth. Users dissatisfaction may impact the app's rating, user retention, overall success in a competitive market.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Distribution of App Rating in Play Store Data
# Setup the Visualization Setting

sns.set(style='whitegrid')

# plot distribution of App Ratings

plt.figure(figsize=(10,5))
plt.title('Distribution of App Rating',size=20)
sns.histplot(df_psdata['Rating'],bins=50,kde=True)
plt.xlabel('Rating',size=15)
plt.xlim([None,6])
plt.ylabel('Frequency',size=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram charts are beneficial for visualizing the distribution of a single numerical variable. In this scenario, utilizing a histogram chart allowed me to portray the distribution of app ratings from the Play Store data, providing a clear representation of the frequency of various rating levels assigned by users.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Overall Sentiment:**
#
# The majority of users are satisfied with the apps, as evidenced by the high concentration of positive ratings.
#
# **Exceptional Apps:**
#
# A notable fraction of users demonstrates high enthusiasm for the apps, as evidenced by the concentration observed between ratings 4 and 5.
#
# **Areas for Improvement:**
#
# There is some room for improvement, as evidenced by the presence of lower ratings. By analyzing the negative reviews, developers can identify specific areas where the apps can be enhanced.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact**
#
# **Overall Positive Sentiment:**
#
# **Potential Positive Impact:** The dominance of positive sentiment indicates that most apps are well-received, which can contribute to positive user experiences, retention, and potentially attract new users. Positive reviews and satisfaction often lead to positive word-of-mouth contenting to the app's popularity and success.
# Distribution Shape and User Satisfaction:
#
# **Positive Growth Opportunity: **The right-skewed distribution suggests a higher concentration of positively received apps. This implies a general trend of user satisfaction, which can contribute to positive growth. Developers can leverage this positive sentiment to reinforce features users appreciate and further enhance user experiences.
#
# **Negative Growth Consideration**
#
# **Presence of Negative Sentiment:**
# Potential Negative Impact: The existence of negative sentiment, although less prominent, indicates that some apps face dissatisfaction. Unaddressed negative feedback can result in user churn, negative reviews, and a decline in the app's reputation. It may lead to users seeking alternative apps that better meet their expectations.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Distributions of App Types (Free and Paid)
#count the Occurrences of each app type in the 'Type' column
app_type = df_psdata['Type'].value_counts()

#setup parameters for a pie chart
explode=(0,0.1)
plt.figure(figsize=(8,8))

# Set Seaborn color palette
sns.set_palette("pastel")

# create a pie chart to visualize the distribution of Paid and Free apps
plt.pie(app_type, labels=['Free','Paid'], autopct='%1.1f%%', explode=explode)

#set the title of the pie chart
plt.title('Distribution of Free and Paid Apps',size=20)

#Display the pie chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is a good choice for this analysis because it effectively visualizes the proportional breakdown of categorical data. In this case, the data consists of two categories: "Free" and "Paid" apps. Pie charts excel at showcasing the relative size of each category, allowing for a quick and clear understanding of the distribution of free vs paid apps within the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Proportion of Free vs Paid Apps:** The chart reveals the percentage of apps that are free compared to those that require payment. This allows for an immediate comparison between the two categories and highlights the dominant app type within the data.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact**
#
# **Understanding User Preferences:** Knowing the dominant app type (free or paid) allows businesses to tailor their app development strategies. If free apps dominate, focusing on freemium models with in-app purchases could be a good strategy.
#
# **Targeted Marketing: **Insights from the chart can help businesses target their marketing campaigns more effectively. If free apps are popular, focusing on app store optimization (ASO) and user acquisition strategies for free apps becomes crucial.
#
# **Negative Growth Considerations**
#
# While the pie chart doesn't directly indicate negative growth, the insights gained can be used to identify potential risks:
#
# **Overly Saturated Market:** If the chart reveals a significant dominance of either free or paid apps, it could signify market saturation. Developers entering such a market might face intense competition, making it difficult to stand out.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#Top 10 Genres by Installs
# Group by Genre, summing the installs for each genre
genre_installs = df_psdata.groupby("Genres")["Installs"].sum().reset_index()

# Sort by installs in descending order
sorted_genre_installs = genre_installs.sort_values(by="Installs", ascending=False)

# Select the top 10 genres
top_10_genres = sorted_genre_installs.head(10)

# Set up the plot
plt.figure(figsize=(10, 5))

sns.barplot(x="Genres", y="Installs", data=top_10_genres, palette="pastel")

# Customize the plot
plt.xticks(rotation=45, ha="right")

plt.title("Top 10 Genres by Installs", size=20)
plt.xlabel("App Genres", size=15)
plt.ylabel("Installs", size=15)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is an appropriate choice for this analysis because you're comparing discrete categories (genres) and their corresponding quantitative values (installs). It allows for a clear visualization of which genres have the highest number of installs, making it easy to identify the most popular ones.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The chart reveals the following insights:**
#
# **Top Genres:** The chart clearly identifies the top 10 app genres with the highest total number of installs. This information can be valuable for developers who are considering which genres to target for their apps.
#
# **Genre Popularity:** By comparing the bar heights, you can see the relative popularity of each genre. This can help identify trends in user preferences and guide marketing strategies towards genres with a wider audience.
#
# **Distribution of Installs:** The chart allows you to assess the distribution of installs across genres. If there's a significant disparity between the top genres and the rest, it might indicate a market dominated by a few popular genres.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **This analysis can have a positive business impact in several ways:**
#
# **Informed App Development:** By understanding which genres are most popular, developers can make informed decisions about the genre for their app. Targeting a popular genre can increase the app's discoverability and potential user base.
#
# **Effective Marketing Strategies:** Knowing the most popular genres can help with marketing campaigns. Developers can tailor their message and target audience based on genre trends, leading to more effective marketing efforts.
#
# **Identifying Niche Opportunities:** While focusing on popular genres can be beneficial, the chart might also reveal niche genres with a smaller but dedicated user base. Developers can cater to these niches and potentially gain a loyal following.
#
#
#  **Negative Growth Consideration:**
#
# **Competition:** Focusing solely on popular genres can lead to fierce competition, making it harder for new apps to stand out. Developers might need to invest heavily in marketing to differentiate themselves.
#
# **Limited Innovation:** Over-reliance on popular genres might stifle innovation in the market. Developers might be less likely to explore new and unique ideas if they focus on replicating successful formulas.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#Contents Ratings by Installs
# Group by Content Rating, summing the installs for each content rating
content_rating_installs = df_psdata.groupby("Content Rating")['Installs'].sum().reset_index()

# Sort by installs in descending order
sorted_content_rating_installs = content_rating_installs.sort_values(by='Installs', ascending=False)

# Set up the plot
plt.figure(figsize=(10, 5))

# Create a bar chart
sns.barplot(x='Content Rating', y='Installs',hue='Content Rating', data=sorted_content_rating_installs, palette='Set2')

# Customize the plot
plt.title("Content Ratings by Installs", size=20)
plt.xlabel("Total Installs", size=15)
plt.ylabel("Content Ratings", size=15)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This code uses a bar chart to easily compare the total number of installs for each content rating. Bars show which ratings have the most app downloads.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Popular content ratings:** See which content ratings (e.g., Everyone, Teen) have the most installs, indicating user preference.
#
# **Less popular ratings:** Identify content ratings with fewer installs, potentially highlighting under-represented categories.
#
#
#
# **Business impact:**
#
# **Positive impact:** Knowing popular ratings helps developers understand user preferences and tailor content accordingly, potentially attracting more users.
#
# **Negative impact (potential):** Ignoring content ratings with lower installs might lead to missing out on specific user segments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# **Target the right audience:** Focus development efforts on content types that attract a larger user base.
#
# **Increase app discoverability:** Optimize app stores listing and marketing materials to target users interested in those Content Ratings.
#
# **Negative Business Impact:**
#
# **Missing potential users:** Users who prefer less popular Content Ratings might be overlooked.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# sizes groups by Installs
# Define the function togroup apps sizes
def size_groups(value):

  try:
    if value < 20:
      return "Below 20"
    elif 20 <= value < 40:
      return "20-40"
    elif 40 <= value < 60:
      return "40-60"
    elif 60 <= value < 80:
      return "60-80"
    elif 80 <= value < 100:
      return "80-100"
    else:
      return "Above 100"
  except:
    return value

# Example usage
# Apps with Size "Varies with device" have dynamic sizes
# that are not explicitly started, making it challenging to categorize them accurately

# exclude rows Where Size is "Varies with device"
df_filtered_size = df_psdata[df_psdata['Size'] != 'Varies with device']

# Apply the size_groups function to create a new 'size_groups' column
df_filtered_size['Size Group'] = df_filtered_size['Size'].apply(size_groups)

# Group by the Size Group, suming the Installs for each size group
size_group_installs = df_filtered_size.groupby('Size Group')['Installs'].sum().reset_index()

# sort by installs in descending order
sorted_size_group_installs = size_group_installs.sort_values(by='Installs', ascending=False)

# Setup the plot
plt.figure(figsize=(10, 5))
sns.barplot(x='Installs', y='Size Group', data=sorted_size_group_installs, palette='pastel')

#Customize the plot
plt.title('Size Groups by Installs', size=20)
plt.xlabel('Total Installs', size=15)
plt.ylabel('Size Groups (MB)', size=15)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used here because it helps compare categories (Size Groups) with their corresponding values (Installs). This lets you see which app sizes are most popular in terms of total installs.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It shows which app sizes have the most installs. This can inform developers about preferred app sizes among users.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact:**
#
# By understanding what size range gets the most installs, developers can optimize their apps:
#
# **Target efficient size:** They can strive for a balance between features and a smaller size for a smoother user experience.
#
# **Reduce uninstalls due to size:** Knowing user preferences can help avoid creating very large apps that might lead to uninstalls.
#
# **Negative growth considerations:**
#
# Not directly from this chart, but large app sizes with high installs might have negative reviews about storage usage. It's important to consider user feedback within these popular size groups.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Distribution of Ratings by Update Year
# Extract the year from the 'Last Updated' column
df_psdata['Update Year'] = df_psdata['Last Updated'].dt.year

# Set up the regression plot
plt.figure(figsize=(10, 5))
sns.regplot(x="Update Year", y="Rating", data=df_psdata, scatter_kws={'alpha': 0.5}, line_kws={'color': 'red'})

# Customize the plot
plt.title("Distribution of Ratings by Update Year", size=20)
plt.xlabel("Update Year", size=15)
plt.ylabel("Rating", size=15)
plt.xticks(rotation=45, ha="right")

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is a useful tool for visualizing the relationship between two variables. In this case, we are interested in seeing if there is a trend between the year an app was updated and its rating.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows a scatter plot of ratings and update years. While there isn't a perfect linear relationship, there seems to be a slight upward trend. This could indicate that apps that are updated more frequently tend to have higher ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# If the regression line shows a positive trend, it suggests that newer updates are associated with higher ratings, which could attract more users.
#
# Developers can use this insight to prioritize and focus on updates, potentially leading to improved user satisfaction.
#
#
# **Negative Growth Consideration:**
#
# If there is a negative trend or no clear pattern, it might indicate that recent updates are not positively impacting ratings.
#
# This insight could prompt developers to investigate the reasons behind the decline in ratings and take corrective actions.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Top 10 Categories by Average Revenue
# calulate Revenue for each App
df_psdata['Revenue'] = df_psdata['Installs']*df_psdata['Price']

# Group by category and calculate the mean revenue , sorted in descending order
category_revenue = df_psdata.groupby("Category")["Revenue"].mean().sort_values(ascending=False)

# Select the top 10 genres
top_10_categories_revenue = category_revenue.head(10)

# Set up the plot
plt.figure(figsize=(10, 5))

# Title of the plot
plt.title("Top 10 Categories by Average Revenue",size=20)

# Create a bar plot for Top 10 Categories
sns.barplot(x=top_10_categories_revenue.values, y=top_10_categories_revenue.index,  palette="Set3")

# Labeling the x and y axes
plt.xlabel("Average Revenue (USD)", size=15)
plt.ylabel("Category", size=15)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar plot to visualize the Top 10 Categories by Average Revenue.
# Bar plots are effective for comparing values across different categories, making it suitable for ranking and comparing revenue across categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart displays the Top 10 Categories based on their average revenue.
# It gives a clear visual representation of which categories generate the highest average revenue.
# Insights are derived from the heights of the bars, where taller bars indicate higher average revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** Businesses can focus more on the top-performing categories to maximize revenue.
#
# **Negative Impact:** If certain categories show lower average revenue, it might prompt businesses to strategize ways to improve revenue in those areas.
#
#
# **Justification:**
#
# This visual can guide business decisions, helping allocate resources to categories with higher revenue potential.
#
# Negative growth insights can prompt corrective actions to enhance revenue streams in underperforming categories.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Comparing the Revenue and Android Version of the Top 8 Paid Apps in the Play Store
# Set Style to 'whitegrid'
sns.set(style='whitegrid')

# Exclude App with Android Version 'Varies with device'
top_8_paid_apps = df_psdata[df_psdata['Android Ver'] != 'Varies with device'].nlargest(8, 'Revenue', keep='first')

# Set up the plot
plt.figure(figsize=(10, 5))

# Ploting lollipops for Revenue using seaborn barplot
sns.scatterplot(x='App', y='Revenue',hue='Android Ver', data=top_8_paid_apps, palette='Dark2', s=300, zorder=2)

# Ploting bars for Revenue using seaborn barplot
sns.barplot(x='App', y='Revenue', data=top_8_paid_apps, color='darkorange', width=0.08, zorder=1)

# Customize the plot
plt.xticks(rotation=45, ha="right")
plt.title("Top Eight Paid Apps: Revenue and Android Version", size=20)
plt.xlabel("App", size=15)
plt.ylabel("Revenue (USD)", size=15)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a combination of a bar plot and scatter plot created using seaborn. It compares the revenue and Android version of the top 8 paid apps in the Play Store.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The lollipop plot (scatter plot) provides a visual representation of the revenue for each app, distinguishing them by Android version using different colors.
# The bar plot displays the total revenue for each app, allowing for a quick comparison.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:** The visualization helps identify the revenue distribution among the top 8 paid apps, making it easier for stakeholders to understand which apps contribute the most to revenue.
#
# **Business Decision:** This information can guide business decisions such as focusing marketing efforts on high-revenue apps, optimizing app features for specific Android versions, or considering the revenue potential of different versions.
#
# **Negative Growth:**
#
# Negative insights may arise if there are significant revenue discrepancies among the apps. For example, if one app is not performing well in terms of revenue, it may signal a need for further analysis and potential adjustments to improve its market performance.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Sentiment count across categories
# Sets the plot style
sns.set(style='whitegrid')

# Sets the figure size
plt.figure(figsize=(14, 6))

# Groups the data by 'Category' and 'Sentiment' columns, gets the count of each combination and unstacks the result
grouped_df = merged_df.groupby(['Category', 'Sentiment']).size().unstack().reset_index()

# Defines a categorical color palette for sentiments
palette = {'Positive': 'skyblue', 'Negative': 'gray', 'Neutral': 'orange'}

# Creates a bar chart using seaborn with 'hue' for sentiments
sns.barplot(data=grouped_df.melt(id_vars='Category'), x='Category', y='value', hue='Sentiment', palette=palette)

# Adds labels and title to the plot
plt.xlabel('Category', size=15)
plt.xticks(rotation=90)
plt.ylabel('Count of sentiments', size=15)
plt.title('Sentiments vs Category', size=20)

# Adding legend
plt.legend(title='Sentiments')

# displaying the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The selected chart is a grouped bar chart created using seaborn.
# The 'hue' parameter is utilized to represent different sentiments (Positive, Negative, Neutral) within each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart visualizes the distribution of sentiments (Positive, Negative, Neutral) across different app categories.
# It helps in comparing the sentiment distribution within each category, providing an overview of how users perceive apps in different domains.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Insights:**
#
# Identifying categories with a high count of positive sentiments can indicate user satisfaction and popularity.
# It may help in tailoring marketing strategies for positively perceived categories.
#
# **Negative Growth Considerations:**
#
# Categories with a significant count of negative sentiments may require attention.
# Negative sentiments could impact user engagement and may indicate areas for improvement.
#
#
# **Overall:**
#
# The insights can guide decision-making processes, allowing the business to focus on categories with positive sentiments for growth.
# Addressing issues in categories with negative sentiments can lead to improvements, positively impacting user perception.

# %% [markdown]
# #### Chart - 11

# %%
# Progression of update counts and distribution of sentiments counts over time
# Grouping by "Update Year" and count the number of updates
update_counts = merged_df['Update Year'].value_counts().sort_index()

# Grouping by "Update Year" and "Sentiment" and count occurrences
sentiment_counts = merged_df.groupby(["Update Year", "Sentiment"]).size().unstack()

# Plotting
plt.figure(figsize=(12, 8))

# Plotting the number of updates received over update years
plt.subplot(2, 1, 1)
sns.lineplot(data=update_counts, marker='o', label='Number of Updates', color="darkblue", markersize=10)
plt.title("Number of Updates and Sentiments over Update Years", size=15)
plt.ylabel("Number of Updates",size=15)

# Plotting sentiment distribution across update years
plt.subplot(2, 1, 2)
sns.lineplot(data=sentiment_counts[['Positive', 'Negative', 'Neutral']], markers=['o', 'o', 'o'], palette="dark", linewidth=2, markersize=10)
plt.xlabel("Update Year",size=15)
plt.ylabel('Number of Sentiments',size=15)

# Adjust layout for better readability
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The line charts were chosen to represent the progression of update counts and the distribution of sentiments over time.
#
# Line charts are suitable for showing trends over continuous variables, making them appropriate for visualizing the progression of update counts across different years and sentiment distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Number of Updates over Years:**
# The first subplot reveals that the number of updates has varied across different years, with some years experiencing a higher frequency of updates than others.
#
# **Sentiment Distribution:**
# The second subplot illustrates the distribution of sentiments (Positive, Negative, Neutral) over the years. It allows for a visual understanding of how sentiments have fluctuated across different update years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Insights:**
#
# Identifying peak years of update activity may provide insights into successful strategies or periods of innovation.
#
# Understanding sentiment distribution helps gauge user reactions to updates, enabling targeted improvements.
#
# Positive sentiments could correlate with successful updates, potentially driving user engagement and satisfaction.
#
#
# **Negative Growth Considerations:**
#
# If negative sentiments coincide with specific years, it may indicate issues or challenges during those periods.
#
# Negative sentiments might lead to a decline in user satisfaction, affecting user retention and app performance.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Relationship between Sentiment Polarity, Rating and Installs
# Set Style to 'whitegrid'
sns.set(style='whitegrid')

# Set up the plot
plt.figure(figsize=(10, 5))

# Scatter plot with size based on the number of Installs
sns.scatterplot(x='Rating', y='Sentiment_Polarity',size='Installs', data=play_store_df, sizes=(50,300), edgecolor='white',  legend=True)

# Customize the plot
plt.title("Sentiment Polarity By Rating and Installs", size=20)
plt.xlabel("Rating", size=15)
plt.ylabel("Average Sentiment Polarity", size=15)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart is a scatter plot with the x-axis representing "Rating," the y-axis representing "Sentiment Polarity," and the size of each point representing the "Installs" for each app.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot visually represents the relationship between the rating of the apps, their sentiment polarity, and the number of installs.
# Larger points indicate higher install counts, allowing for a quick identification of apps with both positive sentiment and high ratings that are widely installed.
# The spread of points provides insights into the diversity of app sentiments across different rating categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
# Positive sentiment combined with high ratings and a large number of installs could indicate successful apps that resonate well with users.
# Understanding this relationship can help businesses focus on creating content or features that align with positive sentiment, potentially attracting more users and increasing installs.
#
# **Negative Growth Insights:**
# There may be instances where apps with high ratings have low sentiment polarity or vice versa. This could indicate a potential area for improvement.
# Identifying apps with low installs despite positive sentiment and high ratings may suggest a need for marketing strategies or improvements in app visibility.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Relationship between Sentiment Subjectivity and Sentiment Polarity

# Set up the plot
plt.figure(figsize=(12, 6))

# Scatter plot with size based on the number of Installs
sns.scatterplot(x='Sentiment_Subjectivity', y='Sentiment_Polarity',hue='Sentiment', data=merged_df, palette='Set2')

# Customize the plot
plt.title("Relationship between Sentiment Subjectivity and Sentiment Polarity", size=20)
plt.xlabel("Sentiment Subjectivity", size=15)
plt.ylabel("Sentiment Polarity", size=15)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot with sentiment subjectivity on the x-axis, sentiment polarity on the y-axis, and color-coded by sentiment was chosen.
# Scatter plots are effective for visualizing relationships between two continuous variables, and color-coding by sentiment allows for the differentiation of data points.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot reveals the distribution of sentiment subjectivity and polarity for different sentiments (positive, negative, neutral).
#
# Clusters or patterns in the plot may indicate trends or relationships between subjectivity and polarity for each sentiment category.
#
# Examining the concentration of points in different regions can provide insights into the sentiment characteristics of the analyzed data.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# Understanding the relationship between sentiment subjectivity and polarity can help in refining sentiment analysis models.
#
# Businesses can tailor their strategies based on the sentiment characteristics of user reviews or feedback.
#
# **Negative Growth Considerations:**
#
# Negative growth considerations may arise if the analysis indicates inconsistencies or challenges in sentiment classification.
#
# If there are significant overlaps or ambiguity in the sentiment categories, it may affect the accuracy of sentiment analysis models.
#
# **Justification:**
#
# Clear patterns and separations between sentiment clusters suggest a robust sentiment analysis model, contributing to positive business impact.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Relationship among RRating , Reviews, Installs, Price, Sentiment Polarity and Sentiment Subjectivity
# Selecting numerical columns from the merged dataframe
numerical_columns = merged_df[['Rating', 'Reviews', 'Installs', 'Price', 'Sentiment_Polarity', 'Sentiment_Subjectivity']]

# create a correlation matrix
correlation_matrix = numerical_columns.corr()

# create a heatmap
plt.figure(figsize=(10, 5))
sns.heatmap(correlation_matrix,  annot=True, cmap='rocket', fmt='.2f')
plt.title("Correlation Heatmap", size=20)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The correlation heatmap was chosen to visualize the relationships among different numerical columns such as Rating, Reviews, Installs, Price, Sentiment Polarity, and Sentiment Subjectivity. Heatmaps are effective for displaying correlations between variables, allowing for a quick understanding of how changes in one variable relate to changes in another.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap visually represents the correlation coefficients between pairs of numerical variables. The values range from -1 to 1, where:
#
# Positive values close to 1 indicate a strong positive correlation (variables move in the same direction).
#
# Negative values close to -1 indicate a strong negative correlation (variables move in opposite directions).
#
# Values near 0 indicate a weak or no correlation.
#
# Analyzing the heatmap provides insights into which variables are positively or negatively correlated.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Select the numerical columns you want to analyze
included_columns =merged_df[['Rating', 'Installs', 'Reviews', 'Price', 'Type']]

# Log-transform the 'Installs' and 'Reviews' columns
included_columns['Installs (Log)'] = np.log(included_columns["Installs"])
included_columns['Reviews (Log)'] = np.log10(included_columns['Reviews'])

# Select columns for the pair plot
selected_columns = included_columns[['Rating', 'Installs (Log)', 'Reviews (Log)', 'Price', 'Type']]

# Create a pair plot
sns.pairplot(selected_columns, hue="Type", markers=["o", "s"], palette={"Free": "blue", "Paid": "orange"})

# Add a title to the plot
plt.suptitle("Pair Plot: Rating, Installs, Reviews, Price", x=0.5, y=1.02, fontsize=20)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pair plot was chosen to visualize the relationships between multiple numerical variables simultaneously.
# It allows us to observe pairwise interactions between variables, especially the scatter plots on the diagonal, histograms on the diagonal, and scatter plots for each combination of variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Rating vs. Installs:** Examining how the logarithmically transformed number of installs correlates with app ratings.
#
# **Rating vs. Reviews:** Exploring the relationship between logarithmically transformed reviews and app ratings.
#
# **Installs vs. Reviews:** Understanding the correlation between the logarithmically transformed installs and reviews.
#
# **Rating vs. Price:** Observing how the price of an app may influence its rating.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# **Actionable Recommendations:**
#
# **Strategic Development in Popular Genres:** Focus on creating or refining apps in popular genres, such as Tools, Action, Photography, and Entertainment. This aligns with user preferences and can lead to higher engagement.
#
# **Emphasizes Free Apps:**Free apps overwhelmingly dominate the market, indicating the significance of providing an engaging free version to attract users. Given that the majority of apps are free, focus on monetization strategies that complement the free model, such as in-app purchases, ads, or premium features.
#
# **Optimize App Size:** Recognize the preference for smaller apps, as indicated by the popularity of the below 20s and 20-40 MB size groups. Ensure that new app developments and updates prioritize efficiency and minimal storage requirements to align with user preferences for smaller-sized apps.
#
# **Tailor Content Ratings:** Understand the user preference for Everyone and Teen categories and ensure new apps align with these preferences. Be mindful of the limited interest in Mature and Adults-only categories, adjusting content accordingly.
#
# **Strategic Revenue Generation:** Consider app development or improvements in categories that generate higher revenue, such as Lifestyle, Finance, and Weather. Evaluate user preferences within lower-revenue categories to identify opportunities for enhancement.
#
# **Compatibility with Latest Android Versions:** Given the correlation between higher revenue and compatibility with newer Android versions, prioritize app development and updates for the latest versions of the Android operating system.
#
# **User Engagement in Popular Categories:** Recognize the positive sentiments associated with popular categories like Games, Family, Health and Fitness, Travel and Local, and Dating. Strategically engage users through marketing, promotions, and feature enhancements in these categories.
#
# **Continuous Improvement:** Monitor the progression of update counts and user sentiments over time. Respond to user feedback with timely updates to demonstrate a commitment to app improvement.
#
# **Focus on Positive User Sentiment:** Identify the characteristics of apps with consistently positive sentiment and leverage those aspects in future app development. Encourage and amplify positive user experiences through marketing and feature enhancements.
#
# **Address Negative Feedback:** Investigate apps with negative sentiment to pinpoint specific issues causing dissatisfaction. Prioritize addressing these issues to improve user satisfaction.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project has successfully analyzed the Play Store app dataset using Python, uncovering valuable insights into key factors for app engagement and success. The data visualizations and interpretations provide a comprehensive understanding of user sentiment, app ratings, genre preferences, content suitability, and the impact of updates.
#
# Based on these insights, I have crafted actionable recommendations for the client to optimize app performance and achieve their business objectives. I advise them to focus on fostering positive sentiment, addressing user concerns promptly, catering to user preferences like smaller apps and frequent updates, targeting specific genres and content ratings strategically, and building loyal followings in niche markets.
#
# By embracing a data-driven approach and continuously adapting to user preferences, the client can ensure long-term success in the competitive Android app market.
#
# Analysis By: Anshuman Singh Kourav
#
# Email: anshukaurav09@gmail.com

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
